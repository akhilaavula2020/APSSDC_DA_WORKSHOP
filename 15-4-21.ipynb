# %%
import pandas as rs

# %%
data=rs.read_csv('https://raw.githubusercontent.com/AP-State-Skill-Development-Corporation/Datasets/master/Data%20Analysis/Advertising.csv')

# %%
data
# Out:
#      Unnamed: 0     TV  radio  newspaper  sales
# 0             1  230.1   37.8       69.2   22.1
# 1             2   44.5   39.3       45.1   10.4
# 2             3   17.2   45.9       69.3    9.3
# 3             4  151.5   41.3       58.5   18.5
# 4             5  180.8   10.8       58.4   12.9
# 5             6    8.7   48.9       75.0    7.2
# 6             7   57.5   32.8       23.5   11.8
# 7             8  120.2   19.6       11.6   13.2
# 8             9    8.6    2.1        1.0    4.8
# 9            10  199.8    2.6       21.2   10.6
# 10           11   66.1    5.8       24.2    8.6
# 11           12  214.7   24.0        4.0   17.4
# 12           13   23.8   35.1       65.9    9.2
# 13           14   97.5    7.6        7.2    9.7
# 14           15  204.1   32.9       46.0   19.0
# 15           16  195.4   47.7       52.9   22.4
# 16           17   67.8   36.6      114.0   12.5
# 17           18  281.4   39.6       55.8   24.4
# 18           19   69.2   20.5       18.3   11.3
# ...

# %%
data.describe()
# Out:
#        Unnamed: 0          TV       radio   newspaper       sales
# count  200.000000  200.000000  200.000000  200.000000  200.000000
# mean   100.500000  147.042500   23.264000   30.554000   14.022500
# std     57.879185   85.854236   14.846809   21.778621    5.217457
# min      1.000000    0.700000    0.000000    0.300000    1.600000
# 25%     50.750000   74.375000    9.975000   12.750000   10.375000
# 50%    100.500000  149.750000   22.900000   25.750000   12.900000
# 75%    150.250000  218.825000   36.525000   45.100000   17.400000
# max    200.000000  296.400000   49.600000  114.000000   27.000000

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 200 entries, 0 to 199
# Data columns (total 5 columns):
# Unnamed: 0    200 non-null int64
# TV            200 non-null float64
# radio         200 non-null float64
# newspaper     200 non-null float64
# sales         200 non-null float64
# dtypes: float64(4), int64(1)
# memory usage: 7.9 KB

# %%
data.isna() # to know the null values
# Out:
#      Unnamed: 0     TV  radio  newspaper  sales
# 0         False  False  False      False  False
# 1         False  False  False      False  False
# 2         False  False  False      False  False
# 3         False  False  False      False  False
# 4         False  False  False      False  False
# 5         False  False  False      False  False
# 6         False  False  False      False  False
# 7         False  False  False      False  False
# 8         False  False  False      False  False
# 9         False  False  False      False  False
# 10        False  False  False      False  False
# 11        False  False  False      False  False
# 12        False  False  False      False  False
# 13        False  False  False      False  False
# 14        False  False  False      False  False
# 15        False  False  False      False  False
# 16        False  False  False      False  False
# 17        False  False  False      False  False
# 18        False  False  False      False  False
# ...

# %%
data.isna().sum() # how any null values in each row
# Out:
# Unnamed: 0    0
# TV            0
# radio         0
# newspaper     0
# sales         0
# dtype: int64

# %%
data.isnull().sum() # isnull=isna
# Out:
# Unnamed: 0    0
# TV            0
# radio         0
# newspaper     0
# sales         0
# dtype: int64

# %%
data.isnull().sum().sum() # total how many null values
# Out:
# 0

# %%
data.head(3)
# Out:
#    Unnamed: 0     TV  radio  newspaper  sales
# 0           1  230.1   37.8       69.2   22.1
# 1           2   44.5   39.3       45.1   10.4
# 2           3   17.2   45.9       69.3    9.3

# %%
data.iloc[0][3]
# Out:
# 69.2

# %%
data.loc[0][3]
# Out:
# 69.2

# %%
data.loc[0,'newspaper']
# Out:
# 69.2

# %%
tab_data=rs.read_table('https://raw.githubusercontent.com/AP-State-Skill-Development-Corporation/Datasets/master/Data%20Analysis/chipotle.tsv.txt')

# %%
tab_data
# Out:
#       order_id  quantity                              item_name  \
# 0            1         1           Chips and Fresh Tomato Salsa
# 1            1         1                                   Izze
# 2            1         1                       Nantucket Nectar
# 3            1         1  Chips and Tomatillo-Green Chili Salsa
# 4            2         2                           Chicken Bowl
# 5            3         1                           Chicken Bowl
# 6            3         1                          Side of Chips
# 7            4         1                          Steak Burrito
# 8            4         1                       Steak Soft Tacos
# 9            5         1                          Steak Burrito
# 10           5         1                    Chips and Guacamole
# 11           6         1                   Chicken Crispy Tacos
# 12           6         1                     Chicken Soft Tacos
# 13           7         1                           Chicken Bowl
# ...

# %%
tab_data.head(2)
# Out:
#    order_id  quantity                     item_name choice_description  \
# 0         1         1  Chips and Fresh Tomato Salsa                NaN
# 1         1         1                          Izze       [Clementine]
#
#   item_price
# 0     $2.39
# 1     $3.39

# %%
tab_data.shape
# Out:
# (4622, 5)

# %%
tab_data.info
# Out:
# <bound method DataFrame.info of       order_id  quantity                              item_name  \
# 0            1         1           Chips and Fresh Tomato Salsa
# 1            1         1                                   Izze
# 2            1         1                       Nantucket Nectar
# 3            1         1  Chips and Tomatillo-Green Chili Salsa
# 4            2         2                           Chicken Bowl
# 5            3         1                           Chicken Bowl
# 6            3         1                          Side of Chips
# 7            4         1                          Steak Burrito
# 8            4         1                       Steak Soft Tacos
# 9            5         1                          Steak Burrito
# 10           5         1                    Chips and Guacamole
# 11           6         1                   Chicken Crispy Tacos
# 12           6         1                     Chicken Soft Tacos
# ...

# %%
tab_data.columns
# Out:
# Index(['order_id', 'quantity', 'item_name', 'choice_description',
#        'item_price'],
#       dtype='object')

# %%
tab_data.isna()
# Out:
#       order_id  quantity  item_name  choice_description  item_price
# 0        False     False      False                True       False
# 1        False     False      False               False       False
# 2        False     False      False               False       False
# 3        False     False      False                True       False
# 4        False     False      False               False       False
# 5        False     False      False               False       False
# 6        False     False      False                True       False
# 7        False     False      False               False       False
# 8        False     False      False               False       False
# 9        False     False      False               False       False
# 10       False     False      False                True       False
# 11       False     False      False               False       False
# 12       False     False      False               False       False
# ...

# %%
tab_data.isna().sum()
# Out:
# order_id                 0
# quantity                 0
# item_name                0
# choice_description    1246
# item_price               0
# dtype: int64

# %%
tab_data.isna().sum().sum()
# Out:
# 1246

# %%
tab_data['choice_description'].head()
# Out:
# 0                                                  NaN
# 1                                         [Clementine]
# 2                                              [Apple]
# 3                                                  NaN
# 4    [Tomatillo-Red Chili Salsa (Hot), [Black Beans...
# Name: choice_description, dtype: object

# %%
tab_data.drop('choice_description',axis=1)
# Out:
#       order_id  quantity                              item_name item_price
# 0            1         1           Chips and Fresh Tomato Salsa     $2.39
# 1            1         1                                   Izze     $3.39
# 2            1         1                       Nantucket Nectar     $3.39
# 3            1         1  Chips and Tomatillo-Green Chili Salsa     $2.39
# 4            2         2                           Chicken Bowl    $16.98
# 5            3         1                           Chicken Bowl    $10.98
# 6            3         1                          Side of Chips     $1.69
# 7            4         1                          Steak Burrito    $11.75
# 8            4         1                       Steak Soft Tacos     $9.25
# 9            5         1                          Steak Burrito     $9.25
# 10           5         1                    Chips and Guacamole     $4.45
# 11           6         1                   Chicken Crispy Tacos     $8.75
# ...

# %%
tab_data.columns
# Out:
# Index(['order_id', 'quantity', 'item_name', 'choice_description',
#        'item_price'],
#       dtype='object')

# %%
tab_data.drop('choice_description',axis=1,inplace=True)

# %%
tab_data.columns
# Out:
# Index(['order_id', 'quantity', 'item_name', 'item_price'], dtype='object')

# %%
tab_data.set_index('item_name') # which is used to replace the staring column is replaced to your given column name
# Out:
#                                        order_id  quantity item_price
# item_name
# Chips and Fresh Tomato Salsa                  1         1     $2.39
# Izze                                          1         1     $3.39
# Nantucket Nectar                              1         1     $3.39
# Chips and Tomatillo-Green Chili Salsa         1         1     $2.39
# Chicken Bowl                                  2         2    $16.98
# Chicken Bowl                                  3         1    $10.98
# Side of Chips                                 3         1     $1.69
# Steak Burrito                                 4         1    $11.75
# Steak Soft Tacos                              4         1     $9.25
# Steak Burrito                                 5         1     $9.25
# Chips and Guacamole                           5         1     $4.45
# Chicken Crispy Tacos                          6         1     $8.75
# Chicken Soft Tacos                            6         1     $8.75
# ...

# %%
tab_data.set_index('item_name',inplace=True)

# %%
tab_data.head()
# Out:
#                                        order_id  quantity item_price
# item_name
# Chips and Fresh Tomato Salsa                  1         1     $2.39
# Izze                                          1         1     $3.39
# Nantucket Nectar                              1         1     $3.39
# Chips and Tomatillo-Green Chili Salsa         1         1     $2.39
# Chicken Bowl                                  2         2    $16.98

# %%
dia_data=rs.read_csv('https://raw.githubusercontent.com/AP-State-Skill-Development-Corporation/Datasets/master/Classification/diabetes.csv')

# %%
dia_data
# Out:
#      Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 0              6      148             72             35        0  33.6
# 1              1       85             66             29        0  26.6
# 2              8      183             64              0        0  23.3
# 3              1       89             66             23       94  28.1
# 4              0      137             40             35      168  43.1
# 5              5      116             74              0        0  25.6
# 6              3       78             50             32       88  31.0
# 7             10      115              0              0        0  35.3
# 8              2      197             70             45      543  30.5
# 9              8      125             96              0        0   0.0
# 10             4      110             92              0        0  37.6
# 11            10      168             74              0        0  38.0
# ...

# %%
dia_data.columns
# Out:
# Index(['Pregnancies', 'Glucose', 'BloodPressure', 'SkinThickness', 'Insulin',
#        'BMI', 'DiabetesPedigreeFunction', 'Age', 'Outcome'],
#       dtype='object')

# %%
dia_data.shape
# Out:
# (768, 9)

# %%
dia_data.Outcome.unique() # what are the unique values in this
# Out:
# array([1, 0], dtype=int64)

# %%
dia_data.Insulin.unique()
# Out:
# array([  0,  94, 168,  88, 543, 846, 175, 230,  83,  96, 235, 146, 115,
#        140, 110, 245,  54, 192, 207,  70, 240,  82,  36,  23, 300, 342,
#        304, 142, 128,  38, 100,  90, 270,  71, 125, 176,  48,  64, 228,
#         76, 220,  40, 152,  18, 135, 495,  37,  51,  99, 145, 225,  49,
#         50,  92, 325,  63, 284, 119, 204, 155, 485,  53, 114, 105, 285,
#        156,  78, 130,  55,  58, 160, 210, 318,  44, 190, 280,  87, 271,
#        129, 120, 478,  56,  32, 744, 370,  45, 194, 680, 402, 258, 375,
#        150,  67,  57, 116, 278, 122, 545,  75,  74, 182, 360, 215, 184,
#         42, 132, 148, 180, 205,  85, 231,  29,  68,  52, 255, 171,  73,
#        108,  43, 167, 249, 293,  66, 465,  89, 158,  84,  72,  59,  81,
#        196, 415, 275, 165, 579, 310,  61, 474, 170, 277,  60,  14,  95,
#        237, 191, 328, 250, 480, 265, 193,  79,  86, 326, 188, 106,  65,
#        166, 274,  77, 126, 330, 600, 185,  25,  41, 272, 321, 144,  15,
# ...

# %%
dia_data.Insulin.unique().sum()
# Out:
# 35160

# %%
dia_data[dia_data['Outcome']==1]
# Out:
#      Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 0              6      148             72             35        0  33.6
# 2              8      183             64              0        0  23.3
# 4              0      137             40             35      168  43.1
# 6              3       78             50             32       88  31.0
# 8              2      197             70             45      543  30.5
# 9              8      125             96              0        0   0.0
# 11            10      168             74              0        0  38.0
# 13             1      189             60             23      846  30.1
# 14             5      166             72             19      175  25.8
# 15             7      100              0              0        0  30.0
# 16             0      118             84             47      230  45.8
# 17             7      107             74              0        0  29.6
# ...

# %%
dia_data[dia_data['Outcome']==0].count()
# Out:
# Pregnancies                 500
# Glucose                     500
# BloodPressure               500
# SkinThickness               500
# Insulin                     500
# BMI                         500
# DiabetesPedigreeFunction    500
# Age                         500
# Outcome                     500
# dtype: int64

# %%
dia_data[dia_data['Outcome']==1].count()
# Out:
# Pregnancies                 268
# Glucose                     268
# BloodPressure               268
# SkinThickness               268
# Insulin                     268
# BMI                         268
# DiabetesPedigreeFunction    268
# Age                         268
# Outcome                     268
# dtype: int64

# %%
import pandas as rs

# %%
tab_data2=rs.read_table('https://raw.githubusercontent.com/justmarkham/pandas-videos/master/data/chipotle.tsv')
tab_data2
# Out:
#       order_id  quantity                              item_name  \
# 0            1         1           Chips and Fresh Tomato Salsa
# 1            1         1                                   Izze
# 2            1         1                       Nantucket Nectar
# 3            1         1  Chips and Tomatillo-Green Chili Salsa
# 4            2         2                           Chicken Bowl
# 5            3         1                           Chicken Bowl
# 6            3         1                          Side of Chips
# 7            4         1                          Steak Burrito
# 8            4         1                       Steak Soft Tacos
# 9            5         1                          Steak Burrito
# 10           5         1                    Chips and Guacamole
# 11           6         1                   Chicken Crispy Tacos
# 12           6         1                     Chicken Soft Tacos
# 13           7         1                           Chicken Bowl
# ...

# %%
mov_data=rs.read_table('https://raw.githubusercontent.com/justmarkham/pandas-videos/master/data/u.user')
mov_data
# Out:
#           1|24|M|technician|85711
# 0              2|53|F|other|94043
# 1             3|23|M|writer|32067
# 2         4|24|M|technician|43537
# 3              5|33|F|other|15213
# 4          6|42|M|executive|98101
# 5      7|57|M|administrator|91344
# 6      8|36|M|administrator|05201
# 7            9|29|M|student|01002
# 8            10|53|M|lawyer|90703
# 9             11|39|F|other|30329
# 10            12|28|F|other|06405
# 11         13|47|M|educator|29206
# 12        14|45|M|scientist|55106
# 13         15|49|F|educator|97301
# 14    16|21|M|entertainment|10309
# 15       17|30|M|programmer|06355
# 16            18|35|F|other|37212
# 17        19|40|M|librarian|02138
# 18        20|42|F|homemaker|95660
# 19           21|26|M|writer|30068
# 20           22|25|M|writer|40206
# 21           23|30|F|artist|48197
# 22           24|21|F|artist|94533
# 23         25|39|M|engineer|55107
# 24         26|49|M|engineer|21044
# 25        27|40|F|librarian|30030
# ...

# %%
mov_data=rs.read_table('https://raw.githubusercontent.com/justmarkham/pandas-videos/master/data/u.user',sep='|',header=None)
mov_data
# Out:
#        0   1  2              3      4
# 0      1  24  M     technician  85711
# 1      2  53  F          other  94043
# 2      3  23  M         writer  32067
# 3      4  24  M     technician  43537
# 4      5  33  F          other  15213
# 5      6  42  M      executive  98101
# 6      7  57  M  administrator  91344
# 7      8  36  M  administrator  05201
# 8      9  29  M        student  01002
# 9     10  53  M         lawyer  90703
# 10    11  39  F          other  30329
# 11    12  28  F          other  06405
# 12    13  47  M       educator  29206
# 13    14  45  M      scientist  55106
# 14    15  49  F       educator  97301
# 15    16  21  M  entertainment  10309
# 16    17  30  M     programmer  06355
# 17    18  35  F          other  37212
# 18    19  40  M      librarian  02138
# 19    20  42  F      homemaker  95660
# 20    21  26  M         writer  30068
# 21    22  25  M         writer  40206
# 22    23  30  F         artist  48197
# 23    24  21  F         artist  94533
# ...

# %%
mov_data=rs.read_table('https://raw.githubusercontent.com/justmarkham/pandas-videos/master/data/u.user',sep='|',header=None)
mov_data
# Out:
#        0   1  2              3      4
# 0      1  24  M     technician  85711
# 1      2  53  F          other  94043
# 2      3  23  M         writer  32067
# 3      4  24  M     technician  43537
# 4      5  33  F          other  15213
# 5      6  42  M      executive  98101
# 6      7  57  M  administrator  91344
# 7      8  36  M  administrator  05201
# 8      9  29  M        student  01002
# 9     10  53  M         lawyer  90703
# 10    11  39  F          other  30329
# 11    12  28  F          other  06405
# 12    13  47  M       educator  29206
# 13    14  45  M      scientist  55106
# 14    15  49  F       educator  97301
# 15    16  21  M  entertainment  10309
# 16    17  30  M     programmer  06355
# 17    18  35  F          other  37212
# 18    19  40  M      librarian  02138
# 19    20  42  F      homemaker  95660
# 20    21  26  M         writer  30068
# 21    22  25  M         writer  40206
# 22    23  30  F         artist  48197
# 23    24  21  F         artist  94533
# ...

# %%
mov_data[3].unique()
# Out:
# array(['technician', 'other', 'writer', 'executive', 'administrator',
#        'student', 'lawyer', 'educator', 'scientist', 'entertainment',
#        'programmer', 'librarian', 'homemaker', 'artist', 'engineer',
#        'marketing', 'none', 'healthcare', 'retired', 'salesman', 'doctor'],
#       dtype=object)

# %%
mov_data[mov_data[3]=='student']
# Out:
#        0   1  2        3      4
# 8      9  29  M  student  01002
# 29    30   7  M  student  55436
# 31    32  28  F  student  78741
# 32    33  23  M  student  27510
# 35    36  19  F  student  93117
# 36    37  23  M  student  55105
# 48    49  23  F  student  76111
# 51    52  18  F  student  55105
# 65    66  23  M  student  80521
# 66    67  17  M  student  60402
# 67    68  19  M  student  22904
# 72    73  24  M  student  41850
# 75    76  20  M  student  02215
# 80    81  21  M  student  21218
# 93    94  26  M  student  71457
# 98    99  20  M  student  63129
# 100  101  15  M  student  05146
# 102  103  26  M  student  55108
# 103  104  27  M  student  55108
# 109  110  19  M  student  77840
# 116  117  20  M  student  16125
# 123  124  34  M  student  60615
# 134  135  23  M  student  38401
# 138  139  20  M  student  08904
# 139  140  30  F  student  32250
# 152  153  25  M  student  60641
# 153  154  25  M  student  53703
# 158  159  23  F  student  55346
# ...

# %%
mov_data[mov_data[3]=='student'].count()
# Out:
# 0    196
# 1    196
# 2    196
# 3    196
# 4    196
# dtype: int64

# %%
mov_data[mov_data[3]=='entertainment']
# Out:
#        0   1  2              3      4
# 15    16  21  M  entertainment  10309
# 38    39  41  M  entertainment  01040
# 74    75  24  M  entertainment  08816
# 91    92  32  M  entertainment  80525
# 144  145  31  M  entertainment  V3N4P
# 178  179  15  M  entertainment  20755
# 254  255  23  M  entertainment  07029
# 330  331  33  M  entertainment  91344
# 374  375  17  M  entertainment  37777
# 386  387  33  M  entertainment  37412
# 421  422  26  M  entertainment  94533
# 431  432  22  M  entertainment  50311
# 447  448  23  M  entertainment  10021
# 566  567  24  M  entertainment  10003
# 720  721  24  F  entertainment  11238
# 838  839  38  F  entertainment  90814
# 914  915  50  M  entertainment  60614
# 925  926  49  M  entertainment  01701

# %%
mov_data[mov_data[3]=='entertainment'].count()
# Out:
# 0    18
# 1    18
# 2    18
# 3    18
# 4    18
# dtype: int64

# %% [markdown]
# ## titanic dataset

# %%
tit_data=rs.read_csv('https://raw.githubusercontent.com/AP-State-Skill-Development-Corporation/Datasets/master/Classification/titanic.csv')
tit_data
# Out:
#      survived  pclass                                               name  \
# 0           0       3                            Braund, Mr. Owen Harris
# 1           1       1  Cumings, Mrs. John Bradley (Florence Briggs Th...
# 2           1       3                             Heikkinen, Miss. Laina
# 3           1       1       Futrelle, Mrs. Jacques Heath (Lily May Peel)
# 4           0       3                           Allen, Mr. William Henry
# 5           0       3                                   Moran, Mr. James
# 6           0       1                            McCarthy, Mr. Timothy J
# 7           0       3                     Palsson, Master. Gosta Leonard
# 8           1       3  Johnson, Mrs. Oscar W (Elisabeth Vilhelmina Berg)
# 9           1       2                Nasser, Mrs. Nicholas (Adele Achem)
# 10          1       3                    Sandstrom, Miss. Marguerite Rut
# 11          1       1                           Bonnell, Miss. Elizabeth
# ...

# %%
tit_data.head()
# Out:
#    survived  pclass                                               name  \
# 0         0       3                            Braund, Mr. Owen Harris
# 1         1       1  Cumings, Mrs. John Bradley (Florence Briggs Th...
# 2         1       3                             Heikkinen, Miss. Laina
# 3         1       1       Futrelle, Mrs. Jacques Heath (Lily May Peel)
# 4         0       3                           Allen, Mr. William Henry
#
#       sex   age  sibsp  parch            ticket     fare cabin embarked
# 0    male  22.0      1      0         A/5 21171   7.2500   NaN        S
# 1  female  38.0      1      0          PC 17599  71.2833   C85        C
# 2  female  26.0      0      0  STON/O2. 3101282   7.9250   NaN        S
# 3  female  35.0      1      0            113803  53.1000  C123        S
# 4    male  35.0      0      0            373450   8.0500   NaN        S

# %%
tit_data.shape
# Out:
# (891, 11)

# %%
tit_data.isna().sum()
# Out:
# survived      0
# pclass        0
# name          0
# sex           0
# age         177
# sibsp         0
# parch         0
# ticket        0
# fare          0
# cabin       687
# embarked      2
# dtype: int64

# %%
tit_data['age']
# Out:
# 0      22.0
# 1      38.0
# 2      26.0
# 3      35.0
# 4      35.0
# 5       NaN
# 6      54.0
# 7       2.0
# 8      27.0
# 9      14.0
# 10      4.0
# 11     58.0
# 12     20.0
# 13     39.0
# 14     14.0
# 15     55.0
# 16      2.0
# 17      NaN
# 18     31.0
# 19      NaN
# 20     35.0
# 21     34.0
# 22     15.0
# 23     28.0
# 24      8.0
# 25     38.0
# 26      NaN
# 27     19.0
# 28      NaN
# 29      NaN
#        ...
# 861    21.0
# 862    48.0
# 863     NaN
# 864    24.0
# 865    42.0
# 866    27.0
# 867    31.0
# 868     NaN
# 869     4.0
# 870    26.0
# 871    47.0
# 872    33.0
# 873    47.0
# 874    28.0
# 875    15.0
# 876    20.0
# 877    19.0
# 878     NaN
# 879    56.0
# 880    25.0
# 881    33.0
# 882    22.0
# 883    28.0
# 884    25.0
# 885    39.0
# 886    27.0
# 887    19.0
# 888     NaN
# 889    26.0
# 890    32.0
# Name: age, Length: 891, dtype: float64

# %% [markdown]
# ## if we need to apply any data set to ML,All the columns datatypes must in int or float
# -get_dummies
# -label encoder

# %%
tit_data['age'].unique()
# Out:
# array([22.  , 38.  , 26.  , 35.  ,   nan, 54.  ,  2.  , 27.  , 14.  ,
#         4.  , 58.  , 20.  , 39.  , 55.  , 31.  , 34.  , 15.  , 28.  ,
#         8.  , 19.  , 40.  , 66.  , 42.  , 21.  , 18.  ,  3.  ,  7.  ,
#        49.  , 29.  , 65.  , 28.5 ,  5.  , 11.  , 45.  , 17.  , 32.  ,
#        16.  , 25.  ,  0.83, 30.  , 33.  , 23.  , 24.  , 46.  , 59.  ,
#        71.  , 37.  , 47.  , 14.5 , 70.5 , 32.5 , 12.  ,  9.  , 36.5 ,
#        51.  , 55.5 , 40.5 , 44.  ,  1.  , 61.  , 56.  , 50.  , 36.  ,
#        45.5 , 20.5 , 62.  , 41.  , 52.  , 63.  , 23.5 ,  0.92, 43.  ,
#        60.  , 10.  , 64.  , 13.  , 48.  ,  0.75, 53.  , 57.  , 80.  ,
#        70.  , 24.5 ,  6.  ,  0.67, 30.5 ,  0.42, 34.5 , 74.  ])

# %%
tit_data['age'].mean()
# Out:
# 29.69911764705882

# %%
tit_data['age'].fillna(tit_data['age'].mean(),inplace=True)# fillna for filling null values

# %%
tit_data.isna().sum()
# Out:
# survived      0
# pclass        0
# name          0
# sex           0
# age           0
# sibsp         0
# parch         0
# ticket        0
# fare          0
# cabin       687
# embarked      2
# dtype: int64

# %%
tit_data['age'].isna().sum().sum()
# Out:
# 0

# %%
tit_data['age']
# Out:
# 0      22.000000
# 1      38.000000
# 2      26.000000
# 3      35.000000
# 4      35.000000
# 5      29.699118
# 6      54.000000
# 7       2.000000
# 8      27.000000
# 9      14.000000
# 10      4.000000
# 11     58.000000
# 12     20.000000
# 13     39.000000
# 14     14.000000
# 15     55.000000
# 16      2.000000
# 17     29.699118
# 18     31.000000
# 19     29.699118
# 20     35.000000
# 21     34.000000
# 22     15.000000
# 23     28.000000
# 24      8.000000
# 25     38.000000
# 26     29.699118
# 27     19.000000
# 28     29.699118
# 29     29.699118
#          ...
# 861    21.000000
# 862    48.000000
# 863    29.699118
# 864    24.000000
# 865    42.000000
# 866    27.000000
# 867    31.000000
# 868    29.699118
# 869     4.000000
# 870    26.000000
# 871    47.000000
# 872    33.000000
# 873    47.000000
# 874    28.000000
# 875    15.000000
# 876    20.000000
# 877    19.000000
# 878    29.699118
# 879    56.000000
# 880    25.000000
# 881    33.000000
# ...

# %%
tit_data['cabin'].unique()
# Out:
# array([nan, 'C85', 'C123', 'E46', 'G6', 'C103', 'D56', 'A6',
#        'C23 C25 C27', 'B78', 'D33', 'B30', 'C52', 'B28', 'C83', 'F33',
#        'F G73', 'E31', 'A5', 'D10 D12', 'D26', 'C110', 'B58 B60', 'E101',
#        'F E69', 'D47', 'B86', 'F2', 'C2', 'E33', 'B19', 'A7', 'C49', 'F4',
#        'A32', 'B4', 'B80', 'A31', 'D36', 'D15', 'C93', 'C78', 'D35',
#        'C87', 'B77', 'E67', 'B94', 'C125', 'C99', 'C118', 'D7', 'A19',
#        'B49', 'D', 'C22 C26', 'C106', 'C65', 'E36', 'C54',
#        'B57 B59 B63 B66', 'C7', 'E34', 'C32', 'B18', 'C124', 'C91', 'E40',
#        'T', 'C128', 'D37', 'B35', 'E50', 'C82', 'B96 B98', 'E10', 'E44',
#        'A34', 'C104', 'C111', 'C92', 'E38', 'D21', 'E12', 'E63', 'A14',
#        'B37', 'C30', 'D20', 'B79', 'E25', 'D46', 'B73', 'C95', 'B38',
#        'B39', 'B22', 'C86', 'C70', 'A16', 'C101', 'C68', 'A10', 'E68',
#        'B41', 'A20', 'D19', 'D50', 'D9', 'A23', 'B50', 'A26', 'D48',
# ...

# %%
tit_data.drop('cabin',axis=1,inplace=True)# this is for delete columns

# %%
tit_data.isna().sum()
# Out:
# survived    0
# pclass      0
# name        0
# sex         0
# age         0
# sibsp       0
# parch       0
# ticket      0
# fare        0
# embarked    2
# dtype: int64

# %%
tit_data['embarked'].unique()
# Out:
# array(['S', 'C', 'Q', nan], dtype=object)

# %%
tit_data[tit_data['embarked']=='S'].count()
# Out:
# survived    644
# pclass      644
# name        644
# sex         644
# age         644
# sibsp       644
# parch       644
# ticket      644
# fare        644
# embarked    644
# dtype: int64

# %%
tit_data[tit_data['embarked']=='C'].count()
# Out:
# survived    168
# pclass      168
# name        168
# sex         168
# age         168
# sibsp       168
# parch       168
# ticket      168
# fare        168
# embarked    168
# dtype: int64

# %%
tit_data[tit_data['embarked']=='Q'].count()
# Out:
# survived    77
# pclass      77
# name        77
# sex         77
# age         77
# sibsp       77
# parch       77
# ticket      77
# fare        77
# embarked    77
# dtype: int64

# %%
tit_data['embarked'].fillna('S',inplace=True)b
# Out:
#   File "<ipython-input-146-cd52199a78e8>", line 1
#     tit_data['embarked'].fillna('S',inplace=True)b
#                                                  ^
# SyntaxError: invalid syntax

# %%
tit_data['embarked'].isna().sum()
# Out:
# 2

# %%
tit_data.isna().sum()
# Out:
# survived    0
# pclass      0
# name        0
# sex         0
# age         0
# sibsp       0
# parch       0
# ticket      0
# fare        0
# embarked    2
# dtype: int64

# %%
tit_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 10 columns):
# survived    891 non-null int64
# pclass      891 non-null int64
# name        891 non-null object
# sex         891 non-null object
# age         891 non-null float64
# sibsp       891 non-null int64
# parch       891 non-null int64
# ticket      891 non-null object
# fare        891 non-null float64
# embarked    889 non-null object
# dtypes: float64(2), int64(4), object(4)
# memory usage: 69.7+ KB

# %%
rs.get_dummies
# Out:
# <function pandas.core.reshape.reshape.get_dummies>

# %%
rs.get_dummies(tit_data['sex'])
# Out:
#      female  male
# 0         0     1
# 1         1     0
# 2         1     0
# 3         1     0
# 4         0     1
# 5         0     1
# 6         0     1
# 7         0     1
# 8         1     0
# 9         1     0
# 10        1     0
# 11        1     0
# 12        0     1
# 13        0     1
# 14        1     0
# 15        1     0
# 16        0     1
# 17        0     1
# 18        1     0
# 19        1     0
# 20        0     1
# 21        0     1
# 22        1     0
# 23        0     1
# 24        1     0
# 25        1     0
# 26        0     1
# 27        0     1
# 28        1     0
# 29        0     1
# ..      ...   ...
# 861       0     1
# 862       1     0
# 863       1     0
# 864       0     1
# 865       1     0
# 866       1     0
# 867       0     1
# 868       0     1
# 869       0     1
# 870       0     1
# 871       1     0
# 872       0     1
# 873       0     1
# 874       1     0
# 875       1     0
# 876       0     1
# 877       0     1
# 878       0     1
# ...

# %%
from sklearn.preprocessing import LabelEncoder
lab=LabelEncoder()

# %%
tit_data['sex']=lab.fit_transform(tit_data['sex'])

# %%
rs.get_dummies(tit_data['embarked'])
# Out:
#      C  Q  S
# 0    0  0  1
# 1    1  0  0
# 2    0  0  1
# 3    0  0  1
# 4    0  0  1
# 5    0  1  0
# 6    0  0  1
# 7    0  0  1
# 8    0  0  1
# 9    1  0  0
# 10   0  0  1
# 11   0  0  1
# 12   0  0  1
# 13   0  0  1
# 14   0  0  1
# 15   0  0  1
# 16   0  1  0
# 17   0  0  1
# 18   0  0  1
# 19   1  0  0
# 20   0  0  1
# 21   0  0  1
# 22   0  1  0
# 23   0  0  1
# 24   0  0  1
# 25   0  0  1
# 26   1  0  0
# 27   0  0  1
# 28   0  1  0
# 29   0  0  1
# ..  .. .. ..
# 861  0  0  1
# 862  0  0  1
# 863  0  0  1
# 864  0  0  1
# 865  0  0  1
# 866  1  0  0
# 867  0  0  1
# 868  0  0  1
# 869  0  0  1
# 870  0  0  1
# 871  0  0  1
# 872  0  0  1
# 873  0  0  1
# 874  1  0  0
# 875  1  0  0
# 876  0  0  1
# 877  0  0  1
# 878  0  0  1
# 879  1  0  0
# 880  0  0  1
# 881  0  0  1
# 882  0  0  1
# 883  0  0  1
# 884  0  0  1
# 885  0  1  0
# 886  0  0  1
# 887  0  0  1
# 888  0  0  1
# 889  1  0  0
# 890  0  1  0
#
# [891 rows x 3 columns]

# %%
tit_data['embarked']=lab.fit_transform(tit_data['embarked'])
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-157-dfc26c6450e8> in <module>()
# ----> 1 tit_data['embarked']=lab.fit_transform(tit_data['embarked'])
#
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\preprocessing\label.py in fit_transform(self, y)
#     110         """
#     111         y = column_or_1d(y, warn=True)
# --> 112         self.classes_, y = np.unique(y, return_inverse=True)
#     113         return y
#     114
#
# C:\ProgramData\Anaconda3\lib\site-packages\numpy\lib\arraysetops.py in unique(ar, return_index, return_inverse, return_counts, axis)
#     208     ar = np.asanyarray(ar)
#     209     if axis is None:
# --> 210         return _unique1d(ar, return_index, return_inverse, return_counts)
#     211     if not (-ar.ndim <= axis < ar.ndim):
#     212         raise ValueError('Invalid axis kwarg specified for unique')
#
# ...

# %% [markdown]
# ## remove duplicate data

# %%
import pandas as pd

# %%
tit_data.info()

# %%
dict1={'students':['ram','ranga','akhi','akhi'],'sports':['cricket','basketball','badminton','badminton'],'subject':['python','java','c','c']}

# %%
data1=pd.DataFrame(dict1)
data1
# Out:
#        sports students subject
# 0     cricket      ram  python
# 1  basketball    ranga    java
# 2   badminton     akhi       c
# 3   badminton     akhi       c

# %% [markdown]
# ## dataframe.duplicated()

# %%
data1.duplicated()
# Out:
# 0    False
# 1    False
# 2    False
# 3    False
# dtype: bool

# %%
data1[data1.duplicated()] ## to find only duplicate row
# Out:
#       sports students subject
# 3  badminton     akhi       c

# %% [markdown]
# ## dataframe.drop_duplicates()

# %%
data1.drop_duplicates()
# Out:
#        sports students subject
# 0     cricket      ram  python
# 1  basketball    ranga    java
# 2   badminton     akhi       c

# %%
data1
# Out:
#        sports students subject
# 0     cricket      ram  python
# 1  basketball    ranga    java
# 2   badminton     akhi       c
# 3   badminton     akhi       c

# %%
data1.drop_duplicates(inplace=True)

# %%
data1
# Out:
#        sports students subject
# 0     cricket      ram  python
# 1  basketball    ranga    java
# 2   badminton     akhi       c

# %% [markdown]
# ## data preprocessing
# - data preprocessing is used todetect outliers

# %%
import matplotlib.pyplot as plt
list1=[1,1.2,3,3,2,9]
list2=[0,0,0,1,1,5]
plt.scatter(list1,list2)

# %% [markdown]
# ## scikit-learn
#   ----- one of the python library which is important for machine learing
#   ----- scikit learn contain machine learing models like KNN,K-means,etc.,

# %%
import sklearn

# %% [markdown]
# ## scaling models
#  - MinMax scaler
#  - robust scaler
#  - standaritization
#  - Normalization

# %% [markdown]
# ## MinMax scaler
#  - it will scale all the data point in between 0 to 1(or -1 to 1)

# %% [markdown]
# ## MinMax scaler formula
# ### (xi-min(x))/(max(x)-min(x))

# %%
d1=pd.read_csv('https://raw.githubusercontent.com/nagamounika5/Datasets/master/Advertisement.csv')

# %%
d1
# Out:
#      Unnamed: 0     TV  radio  newspaper  sales
# 0             1  230.1   37.8       69.2   22.1
# 1             2   44.5   39.3       45.1   10.4
# 2             3   17.2   45.9       69.3    9.3
# 3             4  151.5   41.3       58.5   18.5
# 4             5  180.8   10.8       58.4   12.9
# 5             6    8.7   48.9       75.0    7.2
# 6             7   57.5   32.8       23.5   11.8
# 7             8  120.2   19.6       11.6   13.2
# 8             9    8.6    2.1        1.0    4.8
# 9            10  199.8    2.6       21.2   10.6
# 10           11   66.1    5.8       24.2    8.6
# 11           12  214.7   24.0        4.0   17.4
# 12           13   23.8   35.1       65.9    9.2
# 13           14   97.5    7.6        7.2    9.7
# 14           15  204.1   32.9       46.0   19.0
# 15           16  195.4   47.7       52.9   22.4
# 16           17   67.8   36.6      114.0   12.5
# 17           18  281.4   39.6       55.8   24.4
# 18           19   69.2   20.5       18.3   11.3
# ...

# %%
d1.isna().sum()
# Out:
# Unnamed: 0    0
# TV            0
# radio         0
# newspaper     0
# sales         0
# dtype: int64

# %%
d1.drop(['Unnamed: 0'],axis=1,inplace=True)

# %%
d1.head()
# Out:
#       TV  radio  newspaper  sales
# 0  230.1   37.8       69.2   22.1
# 1   44.5   39.3       45.1   10.4
# 2   17.2   45.9       69.3    9.3
# 3  151.5   41.3       58.5   18.5
# 4  180.8   10.8       58.4   12.9

# %%
d1['TV'].min()
# Out:
# 0.7

# %%
d1['TV'].max()
# Out:
# 296.4

# %%
(230.1-0.7)/(296.4-0.7)
# Out:
# 0.7757862698681096

# %%
from sklearn.preprocessing import MinMaxScaler

# %%
m=MinMaxScaler()
m
# Out:
# MinMaxScaler(copy=True, feature_range=(0, 1))

# %%
m2=m.fit_transform(d1)
m2
# Out:
# array([[0.77578627, 0.76209677, 0.60598065, 0.80708661],
#        [0.1481231 , 0.79233871, 0.39401935, 0.34645669],
#        [0.0557998 , 0.92540323, 0.60686016, 0.30314961],
#        [0.50997633, 0.83266129, 0.51187335, 0.66535433],
#        [0.60906324, 0.21774194, 0.51099384, 0.44488189],
#        [0.02705445, 0.9858871 , 0.65699208, 0.22047244],
#        [0.19208657, 0.66129032, 0.20404573, 0.4015748 ],
#        [0.4041258 , 0.39516129, 0.09938434, 0.45669291],
#        [0.02671627, 0.04233871, 0.00615655, 0.12598425],
#        [0.67331755, 0.05241935, 0.18381706, 0.35433071],
#        [0.2211701 , 0.11693548, 0.21020229, 0.27559055],
#        [0.72370646, 0.48387097, 0.03254178, 0.62204724],
#        [0.07811972, 0.70766129, 0.5769569 , 0.2992126 ],
#        [0.32735881, 0.15322581, 0.06068602, 0.31889764],
#        [0.68785932, 0.66330645, 0.40193492, 0.68503937],
#        [0.65843761, 0.96169355, 0.46262093, 0.81889764],
# ...

# %%
m2=pd.DataFrame(m2,columns=d1.columns)
m2
# Out:
#            TV     radio  newspaper     sales
# 0    0.775786  0.762097   0.605981  0.807087
# 1    0.148123  0.792339   0.394019  0.346457
# 2    0.055800  0.925403   0.606860  0.303150
# 3    0.509976  0.832661   0.511873  0.665354
# 4    0.609063  0.217742   0.510994  0.444882
# 5    0.027054  0.985887   0.656992  0.220472
# 6    0.192087  0.661290   0.204046  0.401575
# 7    0.404126  0.395161   0.099384  0.456693
# 8    0.026716  0.042339   0.006157  0.125984
# 9    0.673318  0.052419   0.183817  0.354331
# 10   0.221170  0.116935   0.210202  0.275591
# 11   0.723706  0.483871   0.032542  0.622047
# 12   0.078120  0.707661   0.576957  0.299213
# 13   0.327359  0.153226   0.060686  0.318898
# 14   0.687859  0.663306   0.401935  0.685039
# 15   0.658438  0.961694   0.462621  0.818898
# 16   0.226919  0.737903   1.000000  0.429134
# 17   0.949273  0.798387   0.488127  0.897638
# 18   0.231654  0.413306   0.158311  0.381890
# 19   0.495773  0.481855   0.165347  0.511811
# ...

# %%
import seaborn as sns

# %%
fig,(ax1,ax2)=plt.subplots(ncols=2,figsize=(9,5))

# %%
fig,(ax1,ax2)=plt.subplots(ncols=2,figsize=(9,5))
sns.kdeplot(d1['TV'],ax=ax1)
sns.kdeplot(d1['newspaper'],ax=ax1)
sns.kdeplot(d1['radio'],ax=ax1)
sns.kdeplot(d1['sales'],ax=ax1)
sns.kdeplot(m2['TV'],ax=ax2)
sns.kdeplot(m2['newspaper'],ax=ax2)
sns.kdeplot(m2['radio'],ax=ax2)
sns.kdeplot(m2['sales'],ax=ax2)

# %%
fig,(ax1,ax2)=plt.subplots(ncols=2,figsize=(9,5))
sns.kdeplot(d1['newspaper'],ax=ax1)

# %%
fig,(ax1,ax2)=plt.subplots(ncols=2,figsize=(9,5))
sns.kdeplot(d1['radio'],ax=ax1)

# %%
fig,(ax1,ax2)=plt.subplots(ncols=2,figsize=(9,5))
sns.kdeplot(d1['sales'],ax=ax1)
